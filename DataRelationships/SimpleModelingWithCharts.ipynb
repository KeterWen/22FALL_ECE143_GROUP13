# %%
'''Modeling Data In data charts using only linear slopes and line of best fit'''
"When the value of ρ is close to zero, generally between -0.1 and +0.1, the variables are said to have no linear relationship (or a very weak linear relationship)."
'''One of the first and basic approach to fit a line through the data points is to create a scatter (replaced with bar chart) plot of (x,y) and draw a straight line that fits the experimental data.'''
'''Thus the following are bar charts of all different data groups affecting GPA with a line of best fit to predict how grades would respond to given predictor variable'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('Maths.csv')

df = pd.DataFrame(data)
print(df.iloc[:, 3])
print(df)
# Make G1 subplots showing correlation  between all 30 columns
numGrades = 3#3
numPredict = 29#29

for i in range(numPredict):
    for j in range(numGrades):
        #data = {'18':20, '# of absences':avg gpa, 'Java':30,
       # 'Python':35}
        #courses = list(data.keys())
        #values = list(data.values())
        predictor_value = df.iloc[:, 29]
        predict_dict = df.groupby([df.iloc[:,i].name])[str('G'+str(j+1))].mean().to_dict()
        plt.bar(predict_dict.keys(),predict_dict.values())
        x = [s for s in predict_dict.keys()]
        if isinstance(x[0], int):
            x = np.array([float(s) for s in predict_dict.keys()])
            y = np.array([s for s in predict_dict.values()])
            a, b = np.polyfit(x, y, 1)
            plt.plot(x, a*x+b) 
        plt.xlabel(df.iloc[:, i].name)
        plt.ylabel("Grades "+ str(j+1))
        plt.title(" Average Grades Per " + str(df.iloc[:,i].name))
        plt.show()
# Out:
# 0      U
# 1      U
# 2      U
# 3      U
# 4      U
#       ..
# 390    U
# 391    U
# 392    R
# 393    R
# 394    U
# Name: address, Length: 395, dtype: object
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# ...

# %% [markdown]
# ## imports the required libraries
# import numpy as np
# import pandas as pd
# from sklearn import linear_model
# import matplotlib.pyplot as plt
# from sklearn.model_selection import train_test_split
#
# data = pd.read_csv('Maths.csv')
# numGrades = 3#3
# numPredict = 30#29
# df = pd.DataFrame(data)
# for i in range(26,numPredict):
#     for j in range(2,numGrades):
#         #data = {'18':20, '# of absences':avg gpa, 'Java':30,
#        # 'Python':35}
#         #courses = list(data.keys())
#         #values = list(data.values())
#         predictor_value = df.iloc[:, 29]
#         predict_dict = df.groupby([df.iloc[:,i].name])[str('G'+str(j+1))].mean().to_dict()
#         plt.scatter(predict_dict.keys(),predict_dict.values())
#         plt.xlabel(df.iloc[:, i].name)
#         plt.ylabel("Grades "+ str(j+1))
#         plt.title(" Average Grades Per " + str(df.iloc[:,i].name))
#         plt.show()
#         reg = linear_model.LinearRegression()
#         if i == 27 or i == 28:
#             xvar = np.array([s for s in predict_dict.keys()]).reshape(-1,1)
#             yvar = np.array([s for s in predict_dict.values()])
#             print(xvar)
#             (X_train, X_test, y_train, y_test) = train_test_split(xvar, yvar, test_size = 0.1)
#             reg.fit(X_train,y_train)
#             plt.plot(X_test, reg.predict(X_test),color='red', marker='*')
#             plt.plot(X_test, y_test,color='red', marker='*')
#             plt.show()

# %%
'''Modeling Data in data charts for Portugeuse'''
"When the value of ρ is close to zero, generally between -0.1 and +0.1, the variables are said to have no linear relationship (or a very weak linear relationship)."
'''One of the first and basic approach to fit a line through the data points is to create a scatter (replaced with bar chart) plot of (x,y) and draw a straight line that fits the experimental data.'''
'''Thus the following are bar charts of all different data groups affecting GPA with a line of best fit to predict how grades would respond to given predictor variable'''
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('Portuguese.csv')

df = pd.DataFrame(data)
print(df.iloc[:, 3])
print(df)
# Make G1 subplots showing correlation  between all 30 columns
numGrades = 3#3
numPredict = 29#29

for i in range(numPredict):
    for j in range(numGrades):
        #data = {'18':20, '# of absences':avg gpa, 'Java':30,
       # 'Python':35}
        #courses = list(data.keys())
        #values = list(data.values())
        predictor_value = df.iloc[:, 29]
        predict_dict = df.groupby([df.iloc[:,i].name])[str('G'+str(j+1))].mean().to_dict()
        plt.bar(predict_dict.keys(),predict_dict.values())
        x = [s for s in predict_dict.keys()]
        if isinstance(x[0], int):
            x = np.array([float(s) for s in predict_dict.keys()])
            y = np.array([s for s in predict_dict.values()])
            a, b = np.polyfit(x, y, 1)
            plt.plot(x, a*x+b) 
        plt.xlabel(df.iloc[:, i].name)
        plt.ylabel("Grades "+ str(j+1))
        plt.title(" Average Grades Per " + str(df.iloc[:,i].name))
        plt.show()
# Out:
# 0      U
# 1      U
# 2      U
# 3      U
# 4      U
#       ..
# 644    R
# 645    U
# 646    U
# 647    U
# 648    R
# Name: address, Length: 649, dtype: object
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# ...
